# %% [markdown]
# <a href="https://colab.research.google.com/github/danielahernandz/Series-de-tiempo-avanzado/blob/main/Efectos_trend_seasonal_resid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Estacionalidad

# %%
import pandas as pd 
import numpy as np
# %matplotlib inline

# %%
airline = pd.read_csv('airline_passengers.csv', index_col=0, parse_dates= True)

# %%
airline
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121
# ...                             ...
# 1960-08-01                      606
# 1960-09-01                      508
# 1960-10-01                      461
# 1960-11-01                      390
# 1960-12-01                      432
#
# [144 rows x 1 columns]

# %%
airline.plot() #Se observa: estacionalidad en el conjunto de datos(picos y bajadas conforman la tendencia en alza), y una tendecia posiblemente exponencial, según el mes del año hay fluctuaciones que se repiten, en los meses de vacaciones hay picos
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# Para descomponer los efectos:
# 1. Aditivo si la tendencia parece ser más lineal.
# 2. Multiplicativo si la tendencia parece ser exponencial.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(airline['Thousands of Passengers'], model='additive')
result.plot();

#trend: patrón de crecimiento general
#estacionalidad(seasonal): se repite año tras año
#residual= es lo que no se explica ni por tendencia o estacionalidad, parece ruido, 
#y es un indicador de donde hay más ruido en el cojunto de datos

# %%
result = seasonal_decompose(airline['Thousands of Passengers'], model='multiplicative')
result.plot();
